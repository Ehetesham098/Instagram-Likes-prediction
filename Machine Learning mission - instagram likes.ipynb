# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sklearn.metrics as sm
import statsmodels.formula.api as smf

# %%
data=pd.read_csv(r"C:\Users\ADMIN\Documents\mlinsta.csv")

# %%
data
# Out:
#     Unnamed: 0  S.No                    USERNAME  \
# 0            0     1               mikequindazzi
# 1            1     2             drgorillapaints
# 2            2     3          aitrading_official
# 3            3     4        opensourcedworkplace
# 4            4     5                 crea.vision
# 5            5     6                 be.masterly
# 6            6     7          lenovoworkstations
# 7            7     8                     kirellb
# 8            8     9                 ethicsandai
# 9            9    10        diworksolucionesdeti
# 10          10    11                    databowl
# 11          11    13               edwisor_india
# 12          12    14                      ubiqum
# 13          13    15  artificialintelligence.a.i
# 14          14    18                 ansonmccade
# 15          15    20               jennifercodes
# 16          16    21                eligible.api
# 17          17    22                   ale_borba
# ...

# %%
data.isnull().any
# Out:
# <bound method DataFrame.any of     Unnamed: 0   S.No  USERNAME  Caption  Followers  Hashtags  \
# 0        False  False     False    False      False     False
# 1        False  False     False    False      False     False
# 2        False  False     False    False      False     False
# 3        False  False     False    False      False     False
# 4        False  False     False    False      False     False
# 5        False  False     False    False      False     False
# 6        False  False     False    False      False     False
# 7        False  False     False    False      False     False
# 8        False  False     False    False      False     False
# 9        False  False     False    False      False     False
# 10       False  False     False    False      False     False
# 11       False  False     False    False      False     False
# 12       False  False     False    False      False     False
# 13       False  False     False    False      False     False
# ...

# %%
drop=['Unnamed: 0','S.No','USERNAME' ,'Caption','Hashtags']

# %%
data.drop(drop,inplace = True,axis = 1)

# %%
data.head()
# Out:
#    Followers Time since posted  Likes
# 0       1600          11 hours    139
# 1        880           2 hours     23
# 2        255           2 hours     25
# 3        340           3 hours     49
# 4        304           3 hours     30

# %%
list1 = data['Followers'].to_list()
print(list1)
# Out:
# [1600, 880, 255, 340, 304, 1231, 259, 1433, 13, 450, 149, 2232, 1061, 533, 2904, 971, 285, 520, 75, 2691, 966, 334, 1041, 4496, 166, 1211, 265, 1618, 279, 279, 828, 12, 894, 610, 226, 1168, 835, 124, 193, 1600, 258, 105, 273, 914, 118, 122, 1180, 3139, 3725, 935, 1766, 2277, 348, 87, 2785, 3448, 530, 3147, 918, 4496, 145, 11, 577, 66, 89, 2014, 151, 2175, 371, 1003, 1200, 383, 955, 2372, 740, 2573, 181, 631, 246, 460, 140, 888, 845, 91, 361, 2455, 361, 262, 1158, 1196, 863, 971, 106, 179, 49, 614, 450, 182, 2039, 741]

# %%
list2= data['Time since posted'].to_list()
print(list2)
# Out:
# ['11 hours', '2 hours', '2 hours', '3 hours', '3 hours', '3 hours', '3 hours', '4 hours', '4 hours', '7 hours', '7 hours', '8 hours', '9 hours', '11 hours', '3 hours', '3 hours', '4 hours', '4 hours', '4 hours', '4 hours', '5 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '20 hours', '4 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '14 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '3 hours', '3 hours', '4 hours', '4 hours', '4 hours', '4 hours', '4 hours', '7 hours', '24 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '3 hours', '2 hours', '3 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '2 hours', '3 hours', '3 hours', '3 hours', '4 hours', '2 hours', '2 hours', '2 hours', '2
# ...

# %%
list3= data['Likes'].to_list()
print(list3)
# Out:
# [139, 23, 25, 49, 30, 18, 35, 86, 22, 18, 31, 48, 80, 94, 28, 53, 29, 46, 30, 34, 198, 19, 20, 11, 10, 46, 25, 148, 43, 37, 90, 19, 14, 30, 273, 13, 93, 24, 18, 136, 24, 8, 41, 81, 16, 31, 24, 51, 43, 20, 25, 157, 17, 24, 65, 349, 17, 10, 21, 11, 16, 10, 27, 16, 19, 29, 31, 41, 19, 40, 21, 50, 20, 10, 35, 119, 11, 55, 12, 29, 28, 43, 31, 14, 33, 24, 43, 9, 29, 16, 32, 46, 12, 20, 24, 31, 42, 10, 222, 109]

# %%
new=[s.strip('hours') for s in list2]

# %%
new
# Out:
# ['11 ',
#  '2 ',
#  '2 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '4 ',
#  '4 ',
#  '7 ',
#  '7 ',
#  '8 ',
#  '9 ',
#  '11 ',
#  '3 ',
#  '3 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '5 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '20 ',
#  '4 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '14 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '3 ',
#  '3 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '4 ',
#  '7 ',
#  '24 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '3 ',
#  '2 ',
#  '3 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '4 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '2 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '3 ',
#  '3 ']

# %%
data1 = pd.DataFrame((zip(list1,new,list3)),columns=['Followers','Time since posted','Likes'])
data1
# Out:
#     Followers Time since posted  Likes
# 0        1600               11     139
# 1         880                2      23
# 2         255                2      25
# 3         340                3      49
# 4         304                3      30
# 5        1231                3      18
# 6         259                3      35
# 7        1433                4      86
# 8          13                4      22
# 9         450                7      18
# 10        149                7      31
# 11       2232                8      48
# 12       1061                9      80
# 13        533               11      94
# 14       2904                3      28
# 15        971                3      53
# 16        285                4      29
# 17        520                4      46
# 18         75                4      30
# 19       2691                4      34
# 20        966                5     198
# 21        334                2      19
# 22       1041                2      20
# ...

# %%
a = data1["Followers"]
b = data1["Likes"]
plt.scatter(a,b,color='red')
plt.title('Followers vs Likes')
plt.xlabel('Followers')
plt.ylabel('Likes')
plt.show()

# %%
c = data1["Time since posted"]
d = data1["Likes"]
plt.scatter(c,d,color='blue')
plt.title('Time since posted vs Likes')
plt.xlabel('Time since posted')
plt.ylabel('Likes')
plt.show()

# %%
a = data1["Followers"]
b = data1["Likes"]
plt.plot(a,b,color='red')
plt.title('Followers vs Likes')
plt.xlabel('Followers')
plt.ylabel('Likes')
plt.show()

# %%
c = data1["Time since posted"]
d = data1["Likes"]
plt.plot(c,d,color='blue')
plt.title('Time since posted vs Likes')
plt.xlabel('Time since posted')
plt.ylabel('Likes')
plt.show()

# %%
sns.set(style="darkgrid", color_codes=True)
a = sns.jointplot('Followers','Likes',  data = data1, kind='reg', height=8)
a.annotate(stats.pearsonr)
plt.show()
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
x=data1.iloc[:,0:2] #Declare dependent variable
y=data1.iloc[:,2] #Declare the target variable

# %%
x.head()
# Out:
#    Followers Time since posted
# 0       1600               11
# 1        880                2
# 2        255                2
# 3        340                3
# 4        304                3

# %%
y.head()
# Out:
# 0    139
# 1     23
# 2     25
# 3     49
# 4     30
# Name: Likes, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=999)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
x_train.shape
# Out:
# (80, 2)

# %%
x_test.shape
# Out:
# (20, 2)

# %%
y_train.shape
# Out:
# (80,)

# %%
y_test.shape
# Out:
# (20,)

# %%
ypred=regressor.predict(x_test)
ypred
# Out:
# array([124.48749812,  30.25997782,  29.7290413 ,  32.9377446 ,
#         63.01212305,  29.64824661,  32.38949493, 153.5324651 ,
#         33.41674167,  47.91505861,  77.38708323,  31.17757462,
#         29.23273108,  29.16347849,  28.82298659,  40.67095039,
#         29.59053612,  30.77360119,  49.09235262,  38.32573973])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)#accuracy
# Out:
# 0.649730259848849

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,ypred)
# Out:
# 455.85767764536484

# %%
#Plot for residual error
plt.style.use('fivethirtyeight')
plt.scatter(regressor.predict(x_train),regressor.predict(x_train) - y_train,color = "red",s=8, label= "Train data")
plt.scatter(regressor.predict(x_test),regressor.predict(x_test) - y_test,color = "blue",s=8, label= "Test data")
plt.hlines(y=0,xmin=0,xmax=50,linewidth=2)
plt.legend( loc = 'upper right')
plt.title("Residual plot")
plt.show()
